# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('Market.csv', header=None)
transactions=[]
for i in range(0,7501):
    transactions.append([str(df.values[i,j]) for j in range(0,20)])
    
from apyori import apriori
rules = apriori(transactions,
                min_support = 0.003,
                min_confidence = 0.2,
                min_lift=2)

# %%
MB = list(rules)
result =[list(MB[i][0])for i in range(0,len(MB))]
result
# Out:
# [['burgers', 'almonds'],
#  ['spaghetti', 'bacon'],
#  ['black tea', 'milk'],
#  ['spaghetti', 'blueberries'],
#  ['body spray', 'french fries'],
#  ['burgers', 'ham'],
#  ['milk', 'cereals'],
#  ['chicken', 'light cream'],
#  ['chocolate', 'tomato sauce'],
#  ['eggs', 'cider'],
#  ['milk', 'cider'],
#  ['mushroom cream sauce', 'escalope'],
#  ['pasta', 'escalope'],
#  ['extra dark chocolate', 'mineral water'],
#  ['flax seed', 'green tea'],
#  ['fresh tuna', 'pancakes'],
#  ['fromage blanc', 'honey'],
#  ['parmesan cheese', 'frozen vegetables'],
#  ['frozen vegetables', 'shrimp'],
#  ['frozen vegetables', 'tomatoes'],
#  ['ground beef', 'grated cheese'],
#  ['green beans', 'spaghetti'],
#  ['herb & pepper', 'ground beef'],
#  ['light cream', 'ground beef'],
#  ['olive oil', 'ground beef'],
#  ['pepper', 'ground beef'],
#  ['rice', 'ground beef'],
#  ['salmon', 'ground beef'],
#  ['spaghetti', 'ground beef'],
#  ['tomato sauce', 'ground beef'],
#  ['olive oil', 'light cream'],
#  ['pancakes', 'light cream'],
#  ['pancakes', 'light mayo'],
#  ['milk', 'meatballs'],
#  ['milk', 'soup'],
#  ['whole wheat pasta', 'milk'],
#  ['nonfat milk', 'mineral water'],
#  ['whole wheat pasta', 'olive oil'],
#  ['pasta', 'shrimp'],
#  ['spaghetti', 'pepper'],
#  ['spaghetti', 'red wine'],
#  ['spaghetti', 'strong cheese'],
#  ['spaghetti', 'tomato sauce'],
#  ['burgers', 'almonds', 'nan'],
#  ['milk', 'avocado', 'mineral water'],
#  ['milk', 'spaghetti', 'avocado'],
#  ['spaghetti', 'bacon', 'nan'],
#  ['black tea', 'milk', 'nan'],
#  ['spaghetti', 'nan', 'blueberries'],
#  ['body spray', 'french fries', 'nan'],
#  ['brownies', 'mineral water', 'eggs'],
#  ['cake', 'burgers', 'chocolate'],
#  ['cake', 'burgers', 'milk'],
#  ['burgers', 'chocolate', 'milk'],
#  ['burgers', 'chocolate', 'shrimp'],
#  ['spaghetti', 'burgers', 'chocolate'],
#  ['burgers', 'chocolate', 'turkey'],
#  ['burgers', 'french fries', 'eggs'],
#  ['burgers', 'green tea', 'eggs'],
#  ['burgers', 'ground beef', 'eggs'],
#  ['burgers', 'pancakes', 'eggs'],
#  ['burgers', 'turkey', 'eggs'],
#  ['burgers', 'milk', 'french fries'],
#  ['burgers', 'spaghetti', 'french fries'],
#  ['burgers', 'frozen vegetables', 'mineral water'],
#  ['burgers', 'green tea', 'milk'],
#  ['burgers', 'milk', 'ground beef'],
#  ['mineral water', 'burgers', 'ground beef'],
#  ['burgers', 'spaghetti', 'ground beef'],
#  ['burgers', 'ham', 'nan'],
#  ['burgers', 'milk', 'mineral water'],
#  ['burgers', 'spaghetti', 'milk'],
#  ['burgers', 'turkey', 'milk'],
#  ['whole wheat rice', 'burgers', 'milk'],
#  ['burgers', 'olive oil', 'mineral water'],
#  ['burgers', 'spaghetti', 'pancakes'],
#  ['whole wheat rice', 'burgers', 'spaghetti'],
#  ['cake', 'chocolate', 'spaghetti'],
#  ['cake', 'turkey', 'eggs'],
#  ['cake', 'frozen smoothie', 'mineral water'],
#  ['cake', 'frozen vegetables', 'tomatoes'],
#  ['cake', 'pancakes', 'green tea'],
#  ['cake', 'spaghetti', 'ground beef'],
#  ['cake', 'milk', 'mineral water'],
#  ['cake', 'olive oil', 'mineral water'],
#  ['cake', 'soup', 'mineral water'],
#  ['cake', 'spaghetti', 'olive oil'],
#  ['cake', 'pancakes', 'spaghetti'],
#  ['cake', 'spaghetti', 'tomatoes'],
#  ['spaghetti', 'ground beef', 'cereals'],
#  ['mineral water', 'milk', 'cereals'],
#  ['milk', 'nan', 'cereals'],
#  ['mineral water', 'spaghetti', 'cereals'],
#  ['chocolate', 'chicken', 'french fries'],
#  ['green tea', 'chocolate', 'chicken'],
#  ['milk', 'chocolate', 'chicken'],
#  ['chocolate', 'chicken', 'mineral water'],
#  ['milk', 'chicken', 'eggs'],
#  ['milk', 'chicken', 'french fries'],
#  ['spaghetti', 'chicken', 'french fries'],
#  ['milk', 'chicken', 'ground beef'],
#  ['spaghetti', 'chicken', 'ground beef'],
#  ['chicken', 'nan', 'light cream'],
#  ['milk', 'chicken', 'mineral water'],
#  ['milk', 'olive oil', 'chicken'],
#  ['milk', 'chicken', 'pancakes'],
#  ['milk', 'spaghetti', 'chicken'],
#  ['olive oil', 'chicken', 'mineral water'],
#  ['pancakes', 'chicken', 'mineral water'],
#  ['soup', 'chicken', 'mineral water'],
#  ['chicken', 'mineral water', 'tomatoes'],
#  ['spaghetti', 'olive oil', 'chicken'],
#  ['pancakes', 'spaghetti', 'chicken'],
#  ['chocolate', 'french fries', 'cookies'],
#  ['spaghetti', 'chocolate', 'cookies'],
#  ['chocolate', 'cooking oil', 'eggs'],
#  ['milk', 'chocolate', 'cooking oil'],
#  ['milk', 'chocolate', 'eggs'],
#  ['chocolate', 'olive oil', 'eggs'],
#  ['milk', 'chocolate', 'escalope'],
#  ['chocolate', 'escalope', 'mineral water'],
#  ['chocolate', 'olive oil', 'french fries'],
#  ['chocolate', 'shrimp', 'french fries'],
#  ['frozen smoothie', 'chocolate', 'milk'],
#  ['chocolate', 'ground beef', 'frozen vegetables'],
#  ['milk', 'chocolate', 'frozen vegetables'],
#  ['chocolate', 'olive oil', 'frozen vegetables'],
#  ['chocolate', 'shrimp', 'frozen vegetables'],
#  ['spaghetti', 'chocolate', 'frozen vegetables'],
#  ['chocolate', 'tomatoes', 'frozen vegetables'],
#  ['chocolate', 'ground beef', 'herb & pepper'],
#  ['milk', 'chocolate', 'ground beef'],
#  ['mineral water', 'chocolate', 'ground beef'],
#  ['chocolate', 'olive oil', 'ground beef'],
#  ['spaghetti', 'chocolate', 'ground beef'],
#  ['milk', 'chocolate', 'mineral water'],
#  ['milk', 'chocolate', 'olive oil'],
#  ['milk', 'chocolate', 'shrimp'],
#  ['milk', 'chocolate', 'soup'],
#  ['spaghetti', 'milk', 'chocolate'],
#  ['milk', 'chocolate', 'turkey'],
#  ['chocolate', 'olive oil', 'mineral water'],
#  ['chocolate', 'soup', 'mineral water'],
#  ['chocolate', 'tomato sauce', 'nan'],
#  ['pancakes', 'chocolate', 'olive oil'],
#  ['spaghetti', 'chocolate', 'olive oil'],
#  ['spaghetti', 'chocolate', 'salmon'],
#  ['spaghetti', 'chocolate', 'shrimp'],
#  ['spaghetti', 'chocolate', 'tomatoes'],
#  ['eggs', 'nan', 'cider'],
#  ['milk', 'nan', 'cider'],
#  ['green tea', 'french fries', 'cookies'],
#  ['milk', 'cooking oil', 'eggs'],
#  ['cooking oil', 'mineral water', 'eggs'],
#  ['spaghetti', 'cooking oil', 'eggs'],
#  ['spaghetti', 'cooking oil', 'ground beef'],
#  ['pancakes', 'cooking oil', 'mineral water'],
#  ['spaghetti', 'cooking oil', 'mineral water'],
#  ['spaghetti', 'cottage cheese', 'mineral water'],
#  ['turkey', 'french fries', 'eggs'],
#  ['frozen vegetables', 'ground beef', 'eggs'],
#  ['milk', 'frozen vegetables', 'eggs'],
#  ['frozen vegetables', 'shrimp', 'eggs'],
#  ['frozen vegetables', 'tomatoes', 'eggs'],
#  ['mineral water', 'grated cheese', 'eggs'],
#  ['spaghetti', 'grated cheese', 'eggs'],
#  ['herb & pepper', 'ground beef', 'eggs'],
#  ['milk', 'ground beef', 'eggs'],
#  ['mineral water', 'ground beef', 'eggs'],
#  ['spaghetti', 'ground beef', 'eggs'],
#  ['milk', 'herb & pepper', 'eggs'],
#  ['spaghetti', 'herb & pepper', 'eggs'],
#  ['milk', 'olive oil', 'eggs'],
#  ['milk', 'shrimp', 'eggs'],
#  ['olive oil', 'mineral water', 'eggs'],
#  ['soup', 'mineral water', 'eggs'],
#  ['spaghetti', 'olive oil', 'eggs'],
#  ['spaghetti', 'red wine', 'eggs'],
#  ['spaghetti', 'salmon', 'eggs'],
#  ['spaghetti', 'soup', 'eggs'],
#  ['spaghetti', 'escalope', 'ground beef'],
#  ['milk', 'escalope', 'mineral water'],
#  ['mushroom cream sauce', 'escalope', 'nan'],
#  ['pasta', 'escalope', 'nan'],
#  ['extra dark chocolate', 'nan', 'mineral water'],
#  ['flax seed', 'green tea', 'nan'],
#  ['frozen smoothie', 'green tea', 'french fries'],
#  ['milk', 'frozen vegetables', 'french fries'],
#  ['frozen vegetables', 'tomatoes', 'french fries'],
#  ['herb & pepper', 'french fries', 'ground beef'],
#  ['milk', 'french fries', 'ground beef'],
#  ['spaghetti', 'french fries', 'ground beef'],
#  ['milk', 'olive oil', 'french fries'],
#  ['milk', 'shrimp', 'french fries'],
#  ['spaghetti', 'olive oil', 'french fries'],
#  ['pancakes', 'spaghetti', 'french fries'],
#  ['spaghetti', 'french wine', 'mineral water'],
#  ['fresh bread', 'frozen vegetables', 'mineral water'],
#  ['fresh bread', 'milk', 'mineral water'],
#  ['fresh tuna', 'pancakes', 'nan'],
#  ['fromage blanc', 'nan', 'honey'],
#  ['spaghetti', 'frozen smoothie', 'frozen vegetables'],
#  ['frozen smoothie', 'spaghetti', 'ground beef'],
#  ['frozen smoothie', 'milk', 'mineral water'],
#  ['frozen smoothie', 'spaghetti', 'milk'],
#  ['frozen smoothie', 'spaghetti', 'pancakes'],
#  ['frozen vegetables', 'green tea', 'tomatoes'],
#  ['milk', 'frozen vegetables', 'ground beef'],
#  ['mineral water', 'frozen vegetables', 'ground beef'],
#  ['frozen vegetables', 'olive oil', 'ground beef'],
#  ['frozen vegetables', 'shrimp', 'ground beef'],
#  ['spaghetti', 'frozen vegetables', 'ground beef'],
#  ['frozen vegetables', 'tomatoes', 'ground beef'],
#  ['frozen vegetables', 'mineral water', 'herb & pepper'],
#  ['frozen vegetables', 'mineral water', 'honey'],
#  ['milk', 'frozen vegetables', 'low fat yogurt'],
#  ['milk', 'frozen vegetables', 'mineral water'],
#  ['milk', 'frozen vegetables', 'olive oil'],
#  ['milk', 'frozen vegetables', 'shrimp'],
#  ['milk', 'frozen vegetables', 'soup'],
#  ['spaghetti', 'milk', 'frozen vegetables'],
#  ['milk', 'frozen vegetables', 'tomatoes'],
#  ['whole wheat rice', 'milk', 'frozen vegetables'],
#  ['frozen vegetables', 'olive oil', 'mineral water'],
#  ['frozen vegetables', 'salmon', 'mineral water'],
#  ['frozen vegetables', 'shrimp', 'mineral water'],
#  ['frozen vegetables', 'soup', 'mineral water'],
#  ['spaghetti', 'frozen vegetables', 'mineral water'],
#  ['frozen vegetables', 'tomatoes', 'mineral water'],
#  ['frozen vegetables', 'turkey', 'mineral water'],
#  ['whole wheat rice', 'frozen vegetables', 'mineral water'],
#  ['parmesan cheese', 'frozen vegetables', 'nan'],
#  ['frozen vegetables', 'shrimp', 'nan'],
#  ['frozen vegetables', 'tomatoes', 'nan'],
#  ['spaghetti', 'frozen vegetables', 'olive oil'],
#  ['spaghetti', 'frozen vegetables', 'shrimp'],
#  ['frozen vegetables', 'shrimp', 'tomatoes'],
#  ['spaghetti', 'frozen vegetables', 'soup'],
#  ['spaghetti', 'frozen vegetables', 'tomatoes'],
#  ['spaghetti', 'whole wheat rice', 'frozen vegetables'],
#  ['spaghetti', 'green tea', 'grated cheese'],
#  ['mineral water', 'ground beef', 'grated cheese'],
#  ['ground beef', 'nan', 'grated cheese'],
#  ['spaghetti', 'ground beef', 'grated cheese'],
#  ['spaghetti', 'herb & pepper', 'grated cheese'],
#  ['milk', 'spaghetti', 'grated cheese'],
#  ['mineral water', 'pancakes', 'grated cheese'],
#  ['mineral water', 'spaghetti', 'grated cheese'],
#  ['pancakes', 'spaghetti', 'grated cheese'],
#  ['green beans', 'spaghetti', 'nan'],
#  ['spaghetti', 'green tea', 'ground beef'],
#  ['green tea', 'ground beef', 'tomatoes'],
#  ['spaghetti', 'olive oil', 'green tea'],
#  ['milk', 'herb & pepper', 'ground beef'],
#  ['mineral water', 'herb & pepper', 'ground beef'],
#  ['herb & pepper', 'nan', 'ground beef'],
#  ['spaghetti', 'herb & pepper', 'ground beef'],
#  ['light cream', 'nan', 'ground beef'],
#  ['milk', 'low fat yogurt', 'ground beef'],
#  ['mineral water', 'low fat yogurt', 'ground beef'],
#  ['spaghetti', 'low fat yogurt', 'ground beef'],
#  ['mineral water', 'milk', 'ground beef'],
#  ['milk', 'olive oil', 'ground beef'],
#  ['milk', 'pancakes', 'ground beef'],
#  ['milk', 'soup', 'ground beef'],
#  ['milk', 'spaghetti', 'ground beef'],
#  ['milk', 'turkey', 'ground beef'],
#  ['mineral water', 'olive oil', 'ground beef'],
#  ['mineral water', 'pancakes', 'ground beef'],
#  ['mineral water', 'salmon', 'ground beef'],
#  ['mineral water', 'shrimp', 'ground beef'],
#  ['mineral water', 'soup', 'ground beef'],
#  ['mineral water', 'spaghetti', 'ground beef'],
#  ['mineral water', 'tomatoes', 'ground beef'],
#  ['mineral water', 'turkey', 'ground beef'],
#  ['olive oil', 'nan', 'ground beef'],
#  ['pepper', 'nan', 'ground beef'],
#  ['rice', 'nan', 'ground beef'],
#  ['salmon', 'nan', 'ground beef'],
#  ['spaghetti', 'nan', 'ground beef'],
#  ['tomato sauce', 'nan', 'ground beef'],
#  ['spaghetti', 'olive oil', 'ground beef'],
#  ['pancakes', 'spaghetti', 'ground beef'],
#  ['spaghetti', 'pepper', 'ground beef'],
#  ['spaghetti', 'salmon', 'ground beef'],
#  ['spaghetti', 'shrimp', 'ground beef'],
#  ['spaghetti', 'soup', 'ground beef'],
#  ['spaghetti', 'tomato sauce', 'ground beef'],
#  ['spaghetti', 'tomatoes', 'ground beef'],
#  ['spaghetti', 'ham', 'mineral water'],
#  ['pancakes', 'herb & pepper', 'mineral water'],
#  ['spaghetti', 'herb & pepper', 'mineral water'],
#  ['spaghetti', 'pancakes', 'herb & pepper'],
#  ['hot dogs', 'spaghetti', 'mineral water'],
#  ['mineral water', 'spaghetti', 'light cream'],
#  ['olive oil', 'nan', 'light cream'],
#  ['pancakes', 'nan', 'light cream'],
#  ['pancakes', 'light mayo', 'nan'],
#  ['milk', 'spaghetti', 'low fat yogurt'],
#  ['pancakes', 'spaghetti', 'low fat yogurt'],
#  ['milk', 'nan', 'meatballs'],
#  ['milk', 'olive oil', 'mineral water'],
#  ['milk', 'shrimp', 'mineral water'],
#  ['milk', 'soup', 'mineral water'],
#  ['milk', 'spaghetti', 'mineral water'],
#  ['milk', 'tomatoes', 'mineral water'],
#  ['milk', 'turkey', 'mineral water'],
#  ['milk', 'olive oil', 'nan'],
#  ['milk', 'soup', 'nan'],
#  ['whole wheat pasta', 'milk', 'nan'],
#  ['milk', 'olive oil', 'pancakes'],
#  ['milk', 'olive oil', 'shrimp'],
#  ['milk', 'soup', 'olive oil'],
#  ['milk', 'spaghetti', 'olive oil'],
#  ['milk', 'shrimp', 'pancakes'],
#  ['spaghetti', 'milk', 'salmon'],
#  ['spaghetti', 'milk', 'soup'],
#  ['milk', 'soup', 'tomatoes'],
#  ['milk', 'spaghetti', 'tomatoes'],
#  ['milk', 'spaghetti', 'turkey'],
#  ['whole wheat pasta', 'milk', 'spaghetti'],
#  ['whole wheat rice', 'milk', 'spaghetti'],
#  ['nonfat milk', 'nan', 'mineral water'],
#  ['olive oil', 'shrimp', 'mineral water'],
#  ['soup', 'olive oil', 'mineral water'],
#  ['spaghetti', 'olive oil', 'mineral water'],
#  ['olive oil', 'tomatoes', 'mineral water'],
#  ['whole wheat pasta', 'olive oil', 'mineral water'],
#  ['pancakes', 'soup', 'mineral water'],
#  ['whole wheat rice', 'pancakes', 'mineral water'],
#  ['spaghetti', 'red wine', 'mineral water'],
#  ['spaghetti', 'salmon', 'mineral water'],
#  ['spaghetti', 'shrimp', 'mineral water'],
#  ['spaghetti', 'soup', 'mineral water'],
#  ['soup', 'tomatoes', 'mineral water'],
#  ['spaghetti', 'tomatoes', 'mineral water'],
#  ['whole wheat pasta', 'spaghetti', 'mineral water'],
#  ['spaghetti', 'olive oil', 'nan'],
#  ['whole wheat pasta', 'olive oil', 'nan'],
#  ['pasta', 'shrimp', 'nan'],
#  ['spaghetti', 'pepper', 'nan'],
#  ['spaghetti', 'nan', 'red wine'],
#  ['strong cheese', 'spaghetti', 'nan'],
#  ['spaghetti', 'tomato sauce', 'nan'],
#  ['pancakes', 'spaghetti', 'olive oil'],
#  ['spaghetti', 'olive oil', 'shrimp'],
#  ['spaghetti', 'olive oil', 'tomatoes'],
#  ['pancakes', 'spaghetti', 'shrimp'],
#  ['pancakes', 'spaghetti', 'turkey'],
#  ['spaghetti', 'shrimp', 'tomatoes'],
#  ['whole wheat rice', 'spaghetti', 'tomatoes'],
#  ['milk', 'avocado', 'mineral water', 'nan'],
#  ['milk', 'spaghetti', 'avocado', 'nan'],
#  ['brownies', 'nan', 'mineral water', 'eggs'],
#  ['cake', 'burgers', 'chocolate', 'nan'],
#  ['cake', 'burgers', 'milk', 'nan'],
#  ['burgers', 'chocolate', 'milk', 'nan'],
#  ['burgers', 'chocolate', 'shrimp', 'nan'],
#  ['spaghetti', 'burgers', 'chocolate', 'nan'],
#  ['burgers', 'chocolate', 'turkey', 'nan'],
#  ['burgers', 'nan', 'french fries', 'eggs'],
#  ['burgers', 'green tea', 'nan', 'eggs'],
#  ['burgers', 'nan', 'ground beef', 'eggs'],
#  ['burgers', 'pancakes', 'nan', 'eggs'],
#  ['burgers', 'turkey', 'nan', 'eggs'],
#  ['burgers', 'milk', 'french fries', 'nan'],
#  ['burgers', 'spaghetti', 'french fries', 'nan'],
#  ['burgers', 'frozen vegetables', 'nan', 'mineral water'],
#  ['burgers', 'green tea', 'milk', 'nan'],
#  ['burgers', 'milk', 'ground beef', 'nan'],
#  ['mineral water', 'burgers', 'nan', 'ground beef'],
#  ['burgers', 'spaghetti', 'nan', 'ground beef'],
#  ['burgers', 'milk', 'mineral water', 'nan'],
#  ['burgers', 'spaghetti', 'milk', 'nan'],
#  ['burgers', 'turkey', 'milk', 'nan'],
#  ['whole wheat rice', 'burgers', 'milk', 'nan'],
#  ['burgers', 'olive oil', 'nan', 'mineral water'],
#  ['burgers', 'spaghetti', 'pancakes', 'nan'],
#  ['whole wheat rice', 'burgers', 'spaghetti', 'nan'],
#  ['cake', 'chocolate', 'spaghetti', 'nan'],
#  ['cake', 'turkey', 'nan', 'eggs'],
#  ['cake', 'frozen smoothie', 'nan', 'mineral water'],
#  ['cake', 'frozen vegetables', 'tomatoes', 'nan'],
#  ['cake', 'pancakes', 'green tea', 'nan'],
#  ['cake', 'spaghetti', 'nan', 'ground beef'],
#  ['cake', 'milk', 'nan', 'mineral water'],
#  ['cake', 'olive oil', 'nan', 'mineral water'],
#  ['cake', 'soup', 'nan', 'mineral water'],
#  ['cake', 'spaghetti', 'olive oil', 'nan'],
#  ['cake', 'pancakes', 'spaghetti', 'nan'],
#  ['cake', 'spaghetti', 'tomatoes', 'nan'],
#  ['spaghetti', 'ground beef', 'nan', 'cereals'],
#  ['mineral water', 'milk', 'nan', 'cereals'],
#  ['mineral water', 'spaghetti', 'nan', 'cereals'],
#  ['chocolate', 'chicken', 'french fries', 'nan'],
#  ['green tea', 'chocolate', 'chicken', 'nan'],
#  ['milk', 'chocolate', 'chicken', 'nan'],
#  ['chocolate', 'chicken', 'nan', 'mineral water'],
#  ['milk', 'chicken', 'nan', 'eggs'],
#  ['milk', 'chicken', 'french fries', 'nan'],
#  ['spaghetti', 'chicken', 'french fries', 'nan'],
#  ['milk', 'chicken', 'nan', 'ground beef'],
#  ['spaghetti', 'chicken', 'nan', 'ground beef'],
#  ['milk', 'chicken', 'nan', 'mineral water'],
#  ['milk', 'olive oil', 'chicken', 'nan'],
#  ['pancakes', 'milk', 'chicken', 'nan'],
#  ['milk', 'spaghetti', 'chicken', 'nan'],
#  ['olive oil', 'chicken', 'nan', 'mineral water'],
#  ['pancakes', 'chicken', 'nan', 'mineral water'],
#  ['soup', 'chicken', 'nan', 'mineral water'],
#  ['chicken', 'nan', 'mineral water', 'tomatoes'],
#  ['spaghetti', 'olive oil', 'chicken', 'nan'],
#  ['pancakes', 'spaghetti', 'chicken', 'nan'],
#  ['chocolate', 'french fries', 'cookies', 'nan'],
#  ['spaghetti', 'chocolate', 'nan', 'cookies'],
#  ['chocolate', 'nan', 'cooking oil', 'eggs'],
#  ['milk', 'chocolate', 'cooking oil', 'nan'],
#  ['frozen vegetables', 'chocolate', 'mineral water', 'eggs'],
#  ['mineral water', 'chocolate', 'ground beef', 'eggs'],
#  ['spaghetti', 'chocolate', 'ground beef', 'eggs'],
#  ['milk', 'chocolate', 'mineral water', 'eggs'],
#  ['milk', 'chocolate', 'nan', 'eggs'],
#  ['chocolate', 'olive oil', 'nan', 'eggs'],
#  ['milk', 'chocolate', 'escalope', 'nan'],
#  ['chocolate', 'escalope', 'nan', 'mineral water'],
#  ['chocolate', 'olive oil', 'french fries', 'nan'],
#  ['chocolate', 'shrimp', 'french fries', 'nan'],
#  ['frozen smoothie', 'chocolate', 'milk', 'nan'],
#  ['mineral water', 'chocolate', 'ground beef', 'frozen vegetables'],
#  ['chocolate', 'nan', 'ground beef', 'frozen vegetables'],
#  ['spaghetti', 'chocolate', 'ground beef', 'frozen vegetables'],
#  ['milk', 'chocolate', 'mineral water', 'frozen vegetables'],
#  ['milk', 'chocolate', 'nan', 'frozen vegetables'],
#  ['spaghetti', 'milk', 'chocolate', 'frozen vegetables'],
#  ['chocolate', 'shrimp', 'mineral water', 'frozen vegetables'],
#  ['spaghetti', 'chocolate', 'mineral water', 'frozen vegetables'],
#  ['chocolate', 'olive oil', 'nan', 'frozen vegetables'],
#  ['chocolate', 'shrimp', 'nan', 'frozen vegetables'],
#  ['spaghetti', 'chocolate', 'nan', 'frozen vegetables'],
#  ['chocolate', 'tomatoes', 'nan', 'frozen vegetables'],
#  ['chocolate', 'nan', 'ground beef', 'herb & pepper'],
#  ['mineral water', 'milk', 'chocolate', 'ground beef'],
#  ['milk', 'chocolate', 'nan', 'ground beef'],
#  ['mineral water', 'chocolate', 'nan', 'ground beef'],
#  ['spaghetti', 'mineral water', 'chocolate', 'ground beef'],
#  ['chocolate', 'olive oil', 'nan', 'ground beef'],
#  ['spaghetti', 'chocolate', 'nan', 'ground beef'],
#  ['milk', 'chocolate', 'nan', 'mineral water'],
#  ['spaghetti', 'milk', 'chocolate', 'mineral water'],
#  ['milk', 'chocolate', 'olive oil', 'nan'],
#  ['milk', 'chocolate', 'shrimp', 'nan'],
#  ['milk', 'chocolate', 'soup', 'nan'],
#  ['spaghetti', 'milk', 'chocolate', 'nan'],
#  ['milk', 'chocolate', 'turkey', 'nan'],
#  ['chocolate', 'olive oil', 'nan', 'mineral water'],
#  ['soup', 'chocolate', 'nan', 'mineral water'],
#  ['spaghetti', 'chocolate', 'olive oil', 'mineral water'],
#  ['spaghetti', 'pancakes', 'chocolate', 'mineral water'],
#  ['spaghetti', 'chocolate', 'shrimp', 'mineral water'],
#  ['pancakes', 'chocolate', 'olive oil', 'nan'],
#  ['spaghetti', 'chocolate', 'olive oil', 'nan'],
#  ['spaghetti', 'chocolate', 'salmon', 'nan'],
#  ['spaghetti', 'chocolate', 'shrimp', 'nan'],
#  ['spaghetti', 'chocolate', 'tomatoes', 'nan'],
#  ['green tea', 'french fries', 'cookies', 'nan'],
#  ['milk', 'nan', 'cooking oil', 'eggs'],
#  ['nan', 'cooking oil', 'mineral water', 'eggs'],
#  ['spaghetti', 'nan', 'cooking oil', 'eggs'],
#  ['spaghetti', 'cooking oil', 'ground beef', 'nan'],
#  ['pancakes', 'cooking oil', 'mineral water', 'nan'],
#  ['spaghetti', 'cooking oil', 'mineral water', 'nan'],
#  ['spaghetti', 'cottage cheese', 'nan', 'mineral water'],
#  ['spaghetti', 'french fries', 'mineral water', 'eggs'],
#  ['turkey', 'nan', 'french fries', 'eggs'],
#  ['frozen vegetables', 'nan', 'ground beef', 'eggs'],
#  ['milk', 'frozen vegetables', 'mineral water', 'eggs'],
#  ['milk', 'frozen vegetables', 'nan', 'eggs'],
#  ['frozen vegetables', 'shrimp', 'nan', 'eggs'],
#  ['frozen vegetables', 'tomatoes', 'nan', 'eggs'],
#  ['mineral water', 'nan', 'grated cheese', 'eggs'],
#  ['spaghetti', 'nan', 'grated cheese', 'eggs'],
#  ['herb & pepper', 'nan', 'ground beef', 'eggs'],
#  ['mineral water', 'milk', 'ground beef', 'eggs'],
#  ['milk', 'nan', 'ground beef', 'eggs'],
#  ['mineral water', 'nan', 'ground beef', 'eggs'],
#  ['mineral water', 'spaghetti', 'ground beef', 'eggs'],
#  ['spaghetti', 'nan', 'ground beef', 'eggs'],
#  ['milk', 'herb & pepper', 'nan', 'eggs'],
#  ['spaghetti', 'herb & pepper', 'nan', 'eggs'],
#  ['milk', 'spaghetti', 'mineral water', 'eggs'],
#  ['milk', 'olive oil', 'nan', 'eggs'],
#  ['milk', 'shrimp', 'nan', 'eggs'],
#  ['olive oil', 'nan', 'mineral water', 'eggs'],
#  ['soup', 'nan', 'mineral water', 'eggs'],
#  ['spaghetti', 'olive oil', 'nan', 'eggs'],
#  ['spaghetti', 'nan', 'red wine', 'eggs'],
#  ['spaghetti', 'salmon', 'nan', 'eggs'],
#  ['spaghetti', 'soup', 'nan', 'eggs'],
#  ['spaghetti', 'escalope', 'nan', 'ground beef'],
#  ['milk', 'escalope', 'nan', 'mineral water'],
#  ['frozen smoothie', 'green tea', 'french fries', 'nan'],
#  ['milk', 'frozen vegetables', 'french fries', 'nan'],
#  ['frozen vegetables', 'tomatoes', 'french fries', 'nan'],
#  ['herb & pepper', 'french fries', 'ground beef', 'nan'],
#  ['milk', 'french fries', 'ground beef', 'nan'],
#  ['spaghetti', 'french fries', 'ground beef', 'nan'],
#  ['milk', 'olive oil', 'french fries', 'nan'],
#  ['milk', 'shrimp', 'french fries', 'nan'],
#  ['spaghetti', 'olive oil', 'french fries', 'nan'],
#  ['pancakes', 'spaghetti', 'french fries', 'nan'],
#  ['spaghetti', 'french wine', 'mineral water', 'nan'],
#  ['fresh bread', 'frozen vegetables', 'nan', 'mineral water'],
#  ['fresh bread', 'milk', 'mineral water', 'nan'],
#  ['spaghetti', 'frozen smoothie', 'frozen vegetables', 'nan'],
#  ['frozen smoothie', 'spaghetti', 'nan', 'ground beef'],
#  ['frozen smoothie', 'milk', 'mineral water', 'nan'],
#  ['frozen smoothie', 'spaghetti', 'milk', 'mineral water'],
#  ['frozen smoothie', 'spaghetti', 'milk', 'nan'],
#  ['frozen smoothie', 'spaghetti', 'pancakes', 'nan'],
#  ['frozen vegetables', 'green tea', 'nan', 'tomatoes'],
#  ['mineral water', 'milk', 'frozen vegetables', 'ground beef'],
#  ['milk', 'frozen vegetables', 'nan', 'ground beef'],
#  ['spaghetti', 'milk', 'frozen vegetables', 'ground beef'],
#  ['mineral water', 'frozen vegetables', 'nan', 'ground beef'],
#  ['spaghetti', 'mineral water', 'frozen vegetables', 'ground beef'],
#  ['frozen vegetables', 'olive oil', 'nan', 'ground beef'],
#  ['frozen vegetables', 'shrimp', 'nan', 'ground beef'],
#  ['spaghetti', 'frozen vegetables', 'nan', 'ground beef'],
#  ['frozen vegetables', 'tomatoes', 'nan', 'ground beef'],
#  ['frozen vegetables', 'nan', 'mineral water', 'herb & pepper'],
#  ['frozen vegetables', 'nan', 'mineral water', 'honey'],
#  ['milk', 'frozen vegetables', 'low fat yogurt', 'nan'],
#  ['milk', 'frozen vegetables', 'nan', 'mineral water'],
#  ['milk', 'frozen vegetables', 'olive oil', 'mineral water'],
#  ['milk', 'frozen vegetables', 'soup', 'mineral water'],
#  ['spaghetti', 'milk', 'frozen vegetables', 'mineral water'],
#  ['milk', 'frozen vegetables', 'olive oil', 'nan'],
#  ['milk', 'frozen vegetables', 'shrimp', 'nan'],
#  ['milk', 'frozen vegetables', 'soup', 'nan'],
#  ['spaghetti', 'milk', 'frozen vegetables', 'nan'],
#  ['milk', 'frozen vegetables', 'tomatoes', 'nan'],
#  ['whole wheat rice', 'milk', 'frozen vegetables', 'nan'],
#  ['frozen vegetables', 'olive oil', 'nan', 'mineral water'],
#  ['frozen vegetables', 'salmon', 'nan', 'mineral water'],
#  ['frozen vegetables', 'shrimp', 'nan', 'mineral water'],
#  ['soup', 'frozen vegetables', 'nan', 'mineral water'],
#  ['spaghetti', 'frozen vegetables', 'nan', 'mineral water'],
#  ['frozen vegetables', 'tomatoes', 'nan', 'mineral water'],
#  ['frozen vegetables', 'turkey', 'nan', 'mineral water'],
#  ['whole wheat rice', 'frozen vegetables', 'nan', 'mineral water'],
#  ['spaghetti', 'frozen vegetables', 'shrimp', 'mineral water'],
#  ['spaghetti', 'frozen vegetables', 'tomatoes', 'mineral water'],
#  ['spaghetti', 'frozen vegetables', 'olive oil', 'nan'],
#  ['spaghetti', 'frozen vegetables', 'shrimp', 'nan'],
#  ['frozen vegetables', 'shrimp', 'nan', 'tomatoes'],
#  ['spaghetti', 'soup', 'frozen vegetables', 'nan'],
#  ['spaghetti', 'frozen vegetables', 'tomatoes', 'nan'],
#  ['spaghetti', 'whole wheat rice', 'frozen vegetables', 'nan'],
#  ['spaghetti', 'green tea', 'nan', 'grated cheese'],
#  ['mineral water', 'ground beef', 'nan', 'grated cheese'],
#  ['spaghetti', 'ground beef', 'nan', 'grated cheese'],
#  ['spaghetti', 'herb & pepper', 'nan', 'grated cheese'],
#  ['milk', 'spaghetti', 'nan', 'grated cheese'],
#  ['mineral water', 'pancakes', 'nan', 'grated cheese'],
#  ['mineral water', 'spaghetti', 'nan', 'grated cheese'],
#  ['pancakes', 'spaghetti', 'nan', 'grated cheese'],
#  ['spaghetti', 'green tea', 'nan', 'ground beef'],
#  ['green tea', 'nan', 'ground beef', 'tomatoes'],
#  ['spaghetti', 'olive oil', 'green tea', 'nan'],
#  ['milk', 'herb & pepper', 'nan', 'ground beef'],
#  ['mineral water', 'herb & pepper', 'nan', 'ground beef'],
#  ['spaghetti', 'herb & pepper', 'nan', 'ground beef'],
#  ['milk', 'low fat yogurt', 'nan', 'ground beef'],
#  ['mineral water', 'low fat yogurt', 'nan', 'ground beef'],
#  ['spaghetti', 'low fat yogurt', 'nan', 'ground beef'],
#  ['mineral water', 'milk', 'nan', 'ground beef'],
#  ['mineral water', 'milk', 'spaghetti', 'ground beef'],
#  ['milk', 'olive oil', 'nan', 'ground beef'],
#  ['milk', 'pancakes', 'nan', 'ground beef'],
#  ['milk', 'soup', 'nan', 'ground beef'],
#  ['milk', 'spaghetti', 'nan', 'ground beef'],
#  ['milk', 'turkey', 'nan', 'ground beef'],
#  ['mineral water', 'olive oil', 'nan', 'ground beef'],
#  ['mineral water', 'pancakes', 'nan', 'ground beef'],
#  ['mineral water', 'salmon', 'nan', 'ground beef'],
#  ['mineral water', 'shrimp', 'nan', 'ground beef'],
#  ['mineral water', 'soup', 'nan', 'ground beef'],
#  ['mineral water', 'spaghetti', 'nan', 'ground beef'],
#  ['mineral water', 'tomatoes', 'nan', 'ground beef'],
#  ['mineral water', 'turkey', 'nan', 'ground beef'],
#  ['mineral water', 'spaghetti', 'olive oil', 'ground beef'],
#  ['mineral water', 'spaghetti', 'pancakes', 'ground beef'],
#  ['mineral water', 'spaghetti', 'tomatoes', 'ground beef'],
#  ['spaghetti', 'olive oil', 'nan', 'ground beef'],
#  ['pancakes', 'spaghetti', 'nan', 'ground beef'],
#  ['spaghetti', 'pepper', 'nan', 'ground beef'],
#  ['spaghetti', 'salmon', 'nan', 'ground beef'],
#  ['spaghetti', 'shrimp', 'nan', 'ground beef'],
#  ['spaghetti', 'soup', 'nan', 'ground beef'],
#  ['spaghetti', 'tomato sauce', 'nan', 'ground beef'],
#  ['spaghetti', 'tomatoes', 'nan', 'ground beef'],
#  ['spaghetti', 'ham', 'mineral water', 'nan'],
#  ['pancakes', 'herb & pepper', 'nan', 'mineral water'],
#  ['spaghetti', 'herb & pepper', 'nan', 'mineral water'],
#  ['spaghetti', 'pancakes', 'herb & pepper', 'nan'],
#  ['hot dogs', 'spaghetti', 'nan', 'mineral water'],
#  ['mineral water', 'spaghetti', 'nan', 'light cream'],
#  ['milk', 'spaghetti', 'low fat yogurt', 'nan'],
#  ['pancakes', 'spaghetti', 'low fat yogurt', 'nan'],
#  ['milk', 'olive oil', 'nan', 'mineral water'],
#  ['milk', 'salmon', 'nan', 'mineral water'],
#  ['milk', 'shrimp', 'nan', 'mineral water'],
#  ['milk', 'soup', 'nan', 'mineral water'],
#  ['milk', 'spaghetti', 'nan', 'mineral water'],
#  ['milk', 'tomatoes', 'nan', 'mineral water'],
#  ['milk', 'turkey', 'nan', 'mineral water'],
#  ['milk', 'spaghetti', 'olive oil', 'mineral water'],
#  ['milk', 'spaghetti', 'shrimp', 'mineral water'],
#  ['milk', 'spaghetti', 'tomatoes', 'mineral water'],
#  ['milk', 'olive oil', 'pancakes', 'nan'],
#  ['milk', 'olive oil', 'shrimp', 'nan'],
#  ['milk', 'soup', 'olive oil', 'nan'],
#  ['milk', 'spaghetti', 'olive oil', 'nan'],
#  ['milk', 'shrimp', 'pancakes', 'nan'],
#  ['spaghetti', 'milk', 'salmon', 'nan'],
#  ['spaghetti', 'milk', 'soup', 'nan'],
#  ['milk', 'soup', 'tomatoes', 'nan'],
#  ['milk', 'spaghetti', 'tomatoes', 'nan'],
#  ['milk', 'spaghetti', 'turkey', 'nan'],
#  ['whole wheat pasta', 'milk', 'spaghetti', 'nan'],
#  ['whole wheat rice', 'milk', 'spaghetti', 'nan'],
#  ['olive oil', 'shrimp', 'nan', 'mineral water'],
#  ['soup', 'olive oil', 'nan', 'mineral water'],
#  ['spaghetti', 'olive oil', 'nan', 'mineral water'],
#  ['olive oil', 'tomatoes', 'nan', 'mineral water'],
#  ['whole wheat pasta', 'olive oil', 'nan', 'mineral water'],
#  ['pancakes', 'soup', 'nan', 'mineral water'],
#  ['whole wheat rice', 'pancakes', 'nan', 'mineral water'],
#  ['red wine', 'spaghetti', 'nan', 'mineral water'],
#  ['spaghetti', 'salmon', 'nan', 'mineral water'],
#  ['spaghetti', 'shrimp', 'nan', 'mineral water'],
#  ['spaghetti', 'soup', 'nan', 'mineral water'],
#  ['soup', 'tomatoes', 'nan', 'mineral water'],
#  ['spaghetti', 'tomatoes', 'nan', 'mineral water'],
#  ['whole wheat pasta', 'spaghetti', 'nan', 'mineral water'],
#  ['pancakes', 'spaghetti', 'olive oil', 'nan'],
#  ['spaghetti', 'olive oil', 'shrimp', 'nan'],
#  ['spaghetti', 'olive oil', 'tomatoes', 'nan'],
#  ['pancakes', 'spaghetti', 'shrimp', 'nan'],
#  ['pancakes', 'spaghetti', 'turkey', 'nan'],
#  ['spaghetti', 'shrimp', 'nan', 'tomatoes'],
#  ['whole wheat rice', 'spaghetti', 'tomatoes', 'nan'],
#  ['eggs', 'chocolate', 'nan', 'mineral water', 'frozen vegetables'],
#  ['ground beef', 'eggs', 'chocolate', 'nan', 'mineral water'],
#  ['ground beef', 'eggs', 'chocolate', 'nan', 'spaghetti'],
#  ['milk', 'eggs', 'chocolate', 'nan', 'mineral water'],
#  ['ground beef', 'chocolate', 'nan', 'mineral water', 'frozen vegetables'],
#  ['ground beef', 'chocolate', 'nan', 'spaghetti', 'frozen vegetables'],
#  ['milk', 'chocolate', 'nan', 'mineral water', 'frozen vegetables'],
#  ['milk', 'chocolate', 'nan', 'spaghetti', 'frozen vegetables'],
#  ['chocolate', 'nan', 'mineral water', 'frozen vegetables', 'shrimp'],
#  ['chocolate', 'nan', 'mineral water', 'spaghetti', 'frozen vegetables'],
#  ['milk', 'ground beef', 'chocolate', 'nan', 'mineral water'],
#  ['ground beef', 'chocolate', 'nan', 'mineral water', 'spaghetti'],
#  ['milk', 'chocolate', 'nan', 'mineral water', 'spaghetti'],
#  ['chocolate', 'olive oil', 'nan', 'mineral water', 'spaghetti'],
#  ['chocolate', 'nan', 'mineral water', 'pancakes', 'spaghetti'],
#  ['chocolate', 'nan', 'mineral water', 'spaghetti', 'shrimp'],
#  ['eggs', 'nan', 'french fries', 'mineral water', 'spaghetti'],
#  ['milk', 'eggs', 'nan', 'mineral water', 'frozen vegetables'],
#  ['milk', 'ground beef', 'eggs', 'nan', 'mineral water'],
#  ['ground beef', 'eggs', 'nan', 'mineral water', 'spaghetti'],
#  ['milk', 'eggs', 'nan', 'mineral water', 'spaghetti'],
#  ['milk', 'nan', 'mineral water', 'spaghetti', 'frozen smoothie'],
#  ['milk', 'ground beef', 'nan', 'mineral water', 'frozen vegetables'],
#  ['milk', 'ground beef', 'nan', 'spaghetti', 'frozen vegetables'],
#  ['ground beef', 'nan', 'mineral water', 'spaghetti', 'frozen vegetables'],
#  ['milk', 'olive oil', 'nan', 'mineral water', 'frozen vegetables'],
#  ['milk', 'nan', 'mineral water', 'soup', 'frozen vegetables'],
#  ['milk', 'nan', 'mineral water', 'spaghetti', 'frozen vegetables'],
#  ['nan', 'mineral water', 'spaghetti', 'frozen vegetables', 'shrimp'],
#  ['nan', 'mineral water', 'spaghetti', 'frozen vegetables', 'tomatoes'],
#  ['milk', 'ground beef', 'nan', 'mineral water', 'spaghetti'],
#  ['ground beef', 'olive oil', 'nan', 'mineral water', 'spaghetti'],
#  ['ground beef', 'nan', 'mineral water', 'pancakes', 'spaghetti'],
#  ['ground beef', 'nan', 'mineral water', 'spaghetti', 'tomatoes'],
#  ['milk', 'olive oil', 'nan', 'mineral water', 'spaghetti'],
#  ['milk', 'nan', 'mineral water', 'spaghetti', 'shrimp'],
#  ['milk', 'nan', 'mineral water', 'spaghetti', 'tomatoes']]

# %%
df
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# 0     green grapes  whole weat flour  yams  cottage cheese  energy drink
# 1              NaN               NaN   NaN             NaN           NaN
# 2              NaN               NaN   NaN             NaN           NaN
# 3              NaN               NaN   NaN             NaN           NaN
# 4        green tea               NaN   NaN             NaN           NaN
# ...            ...               ...   ...             ...           ...
# 7496           NaN               NaN   NaN             NaN           NaN
# 7497     magazines         green tea   NaN             NaN           NaN
# 7498           NaN               NaN   NaN             NaN           NaN
# 7499           NaN               NaN   NaN             NaN           NaN
# 7500           NaN               NaN   NaN             NaN           NaN
#
#                 9               10         11     12     13             14  \
# 0     tomato juice  low fat yogurt  green tea  honey  salad  mineral water
# 1              NaN             NaN        NaN    NaN    NaN            NaN
# 2              NaN             NaN        NaN    NaN    NaN            NaN
# 3              NaN             NaN        NaN    NaN    NaN            NaN
# 4              NaN             NaN        NaN    NaN    NaN            NaN
# ...            ...             ...        ...    ...    ...            ...
# 7496           NaN             NaN        NaN    NaN    NaN            NaN
# 7497           NaN             NaN        NaN    NaN    NaN            NaN
# 7498           NaN             NaN        NaN    NaN    NaN            NaN
# 7499           NaN             NaN        NaN    NaN    NaN            NaN
# 7500           NaN             NaN        NaN    NaN    NaN            NaN
#
#           15                 16               17       18         19
# 0     salmon  antioxydant juice  frozen smoothie  spinach  olive oil
# 1        NaN                NaN              NaN      NaN        NaN
# 2        NaN                NaN              NaN      NaN        NaN
# 3        NaN                NaN              NaN      NaN        NaN
# 4        NaN                NaN              NaN      NaN        NaN
# ...      ...                ...              ...      ...        ...
# 7496     NaN                NaN              NaN      NaN        NaN
# 7497     NaN                NaN              NaN      NaN        NaN
# 7498     NaN                NaN              NaN      NaN        NaN
# 7499     NaN                NaN              NaN      NaN        NaN
# 7500     NaN                NaN              NaN      NaN        NaN
#
# [7501 rows x 20 columns]
